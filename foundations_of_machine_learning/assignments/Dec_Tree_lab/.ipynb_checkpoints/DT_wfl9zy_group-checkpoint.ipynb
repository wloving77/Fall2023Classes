# %% [markdown]
# Congrats! You just graduated UVA's BSDS program and got a job working at a movie studio in Hollywood.
#
# Your boss is the head of the studio and wants to know if they can gain a competitive advantage by predicting new movies that might get high imdb scores (movie rating).
#
# You would like to be able to explain the model to mere mortals but need a fairly robust and flexible approach so you've chosen to use decision trees to get started.
#
# In doing so, similar to  great data scientists of the past you remembered the excellent education provided to you at UVA in a undergrad data science course and have outline 20ish steps that will need to be undertaken to complete this task. As always, you will need to make sure to #comment your work heavily.
#
#  Footnotes:
# -	You can add or combine steps if needed
# -	Also, remember to try several methods during evaluation and always be mindful of how the model will be used in practice.
# - Make sure all your variables are the correct type (factor, character,numeric, etc.)

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
df_movies=pd.read_csv("data/movie_metadata.csv")

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
#  13  cast_total_facebook_likes  5043 non-null   int64
#  14  actor_3_name               5020 non-null   object
#  15  facenumber_in_poster       5030 non-null   float64
#  16  plot_keywords              4890 non-null   object
#  17  movie_imdb_link            5043 non-null   object
#  18  num_user_for_reviews       5022 non-null   float64
#  19  language                   5029 non-null   object
#  20  country                    5038 non-null   object
#  21  content_rating             4740 non-null   object
#  22  budget                     4551 non-null   float64
#  23  title_year                 4935 non-null   float64
#  24  actor_2_facebook_likes     5030 non-null   float64
#  25  imdb_score                 5043 non-null   float64
#  26  aspect_ratio               4714 non-null   float64
#  27  movie_facebook_likes       5043 non-null   int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #2 Ensure all the variables are classified correctly including the target variable and collapse factor variables as needed.

# %%
# No null movies, nice
df_movies['imdb_score'].info()

df_movies.shape
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5043 entries, 0 to 5042
# Series name: imdb_score
# Non-Null Count  Dtype
# --------------  -----
# 5043 non-null   float64
# dtypes: float64(1)
# memory usage: 39.5 KB
# (5043, 28)

# %% [markdown]
# #3 Check for missing variables and correct as needed.

# %%
# damn
df_movies.isna().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
#weird columns that wouldn't work, we'd have to split out the genres and keywords, color is weird too:
cols_to_drop = ['movie_imdb_link', 'plot_keywords', 'genres', 'color']
df_movies_dropped = df_movies.drop(columns=cols_to_drop)

# %%
#going to just arbitrarily fill continuous with the average and categorical with most frequent
from sklearn.impute import SimpleImputer

numerical_columns = df_movies_dropped.select_dtypes(include = ['int', 'float']).columns
categorical_columns = df_movies_dropped.select_dtypes(include = ['object']).columns

num_imputer = SimpleImputer(strategy='mean')
cat_imputer = SimpleImputer(strategy='most_frequent')

df_movies_dropped[numerical_columns] = num_imputer.fit_transform(df_movies_dropped[numerical_columns])
df_movies_dropped[categorical_columns] = cat_imputer.fit_transform(df_movies_dropped[categorical_columns])

# %%
# no NA's! 
df_movies_dropped.isna().sum()
# Out:
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# actor_1_name                 0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %%
cols_to_drop = ['director_name', 'actor_2_name', 'actor_1_name', 'actor_3_name']

df_movies_transformed = df_movies_dropped.drop(columns=cols_to_drop)

# %%
categorical_columns = df_movies_transformed.select_dtypes(include=['object']).columns
df_movies_one_hot = pd.get_dummies(df_movies_transformed, columns=categorical_columns, drop_first=True)

# %% [markdown]
# #4 Guess what, you don't need to scale the data, because DTs don't require this to be done, they make local greedy decisions...keeps getting easier, go to the next step.

# %%
# Sweet

# %% [markdown]
# #5 Determine the baserate or prevalence for the classifier, what does this number mean?

# %%
# This is a regression task so base rate and prevalence aren't applicable.

# %% [markdown]
# #6 Split your data into test, tune, and train. (80/10/10)

# %%
from sklearn.model_selection import train_test_split

# get target and OG df
X = df_movies_one_hot.drop(columns='imdb_score')
y = df_movies_one_hot['imdb_score']


X_train, X_remaining, y_train, y_remaining = train_test_split(X, y, train_size = 0.8)

X_tune, X_test, y_tune, y_test = train_test_split(X_remaining, y_remaining, train_size = 0.5)

# %%
print(f"Train size: {X_train.shape}")
print(f"Tune size: {X_tune.shape}")
print(f"Test size: {X_test.shape}")
# Out:
# Train size: (4034, 141)
# Tune size: (504, 141)
# Test size: (505, 141)

# %% [markdown]
# #7 Create the kfold object for cross validation.

# %%
from sklearn.model_selection import KFold

# Define the number of folds (K)
n_splits = 5  # You can choose the number of splits you want

# Create a K-Fold cross-validation object
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# %% [markdown]
# #8 Create the scoring metric you will use to evaluate your model and the max depth hyperparameter

# %%
scoring = "neg_mean_squared_error"

max_depth = 3

# %% [markdown]
# #9 Build the classifier object

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(max_depth=max_depth)

scores = cross_val_score(model, X_train, y_train, cv=kf, scoring=scoring)

mean = -scores.mean() 
std = scores.std()

# %%
print(f"Mean of Mean Squared Errors: {mean}")
print(f"STD of Mean Squared Errors: {std}")
# Out:
# Mean of Mean Squared Errors: 0.9414555506133979
# STD of Mean Squared Errors: 0.033666606823298785

# %% [markdown]
# #10 Use the kfold object and the scoring metric to find the best hyperparameter value for max depth via the grid search method.

# %%
from sklearn.model_selection import GridSearchCV

# Create your Decision Tree Regressor
regressor = DecisionTreeRegressor()

# Define the parameter grid to search over
param_grid = {
    'max_depth': [2, 3, 4, 5, 6, 7, 8, 9, 10]  # Define the range of max_depth values to search
}

# Create a GridSearchCV object with K-Fold cross-validation
grid_search = GridSearchCV(regressor, param_grid, cv=kf, scoring='neg_mean_squared_error')

# Fit the GridSearchCV object to your data
grid_search.fit(X_train, y_train)

# Get the best hyperparameter values and corresponding MSE score
best_max_depth = grid_search.best_params_
best_mse = -grid_search.best_score_  # Reverse the negative sign to get positive MSE

# %% [markdown]
# #11 Fit the model to the training data.

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [2, 3, 4, 5, 6, 7, 8, 9, 10]},
#              scoring='neg_mean_squared_error')

# %% [markdown]
# #12 What is the best depth value?

# %%
print(f"Best RMSE: {best_mse}")
print(f"Best Depth: {best_max_depth}")
# Out:
# Best RMSE: 0.8665000296130924
# Best Depth: {'max_depth': 6}

# %% [markdown]
# #13 Print out the model

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeRegressor(max_depth=7)

# %% [markdown]
# #14 View the results, comment on how the model performed using several evaluation metrics.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_pred = grid_search.best_estimator_.predict(X_tune)

mae = mean_absolute_error(y_tune, y_pred)
mse = mean_squared_error(y_tune, y_pred)
r_squared = r2_score(y_tune, y_pred)

# Print and comment on the evaluation metrics
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R^2): {r_squared}")



"""
All of our metrics seem to be pretty good, on average we are within one imdb_score point, so the prediction could certainly be worse.

R^2 not ideal though, closer to 1 would be better so that the model features are a little more predictive of the imdb_score

"""
# Out:
# Mean Absolute Error (MAE): 0.6766427516943283
# Mean Squared Error (MSE): 0.8016945198600803
# R-squared (R^2): 0.3420779559433199
# '\nAll of our metrics seem to be pretty good, on average we are within one imdb_score point, so the prediction could certainly be worse.\n\nR^2 not ideal though, closer to 1 would be better so that the model features are a little more predictive of the imdb_score\n\n'

# %% [markdown]
# #15 Which variables appear to be contributing the most (variable importance)

# %%
for feature, importance in zip(X_test.columns, grid_search.best_estimator_.feature_importances_):
    print(f" Feature: {feature}, importance {importance}")
# Out:
#  Feature: num_critic_for_reviews, importance 0.031810030403633775
#  Feature: duration, importance 0.19545719270880793
#  Feature: director_facebook_likes, importance 0.0017460606292825144
#  Feature: actor_3_facebook_likes, importance 0.014589973498547371
#  Feature: actor_1_facebook_likes, importance 0.0010190738634170363
#  Feature: gross, importance 0.056411908369452965
#  Feature: num_voted_users, importance 0.4264122579485081
#  Feature: cast_total_facebook_likes, importance 0.03992957609961394
#  Feature: facenumber_in_poster, importance 0.009817102592987167
#  Feature: num_user_for_reviews, importance 0.00037926986397254065
#  Feature: budget, importance 0.07330862276235219
#  Feature: title_year, importance 0.06641051689614823
#  Feature: actor_2_facebook_likes, importance 0.011672090115371393
#  Feature: aspect_ratio, importance 0.0018839249012145962
#  Feature: movie_facebook_likes, importance 0.004907957459345934
#  Feature: language_Arabic, importance 0.0
#  Feature: language_Aramaic, importance 0.0
#  Feature: language_Bosnian, importance 0.0
#  Feature: language_Cantonese, importance 0.0
#  Feature: language_Chinese, importance 0.0
#  Feature: language_Czech, importance 0.0
#  Feature: language_Danish, importance 0.0
#  Feature: language_Dari, importance 0.0
#  Feature: language_Dutch, importance 0.0
#  Feature: language_Dzongkha, importance 0.0
#  Feature: language_English, importance 0.006428946956840303
#  Feature: language_Filipino, importance 0.0
#  Feature: language_French, importance 0.0
#  Feature: language_German, importance 0.0
#  Feature: language_Greek, importance 0.0
#  Feature: language_Hebrew, importance 0.0
#  Feature: language_Hindi, importance 0.0
#  Feature: language_Hungarian, importance 0.0
#  Feature: language_Icelandic, importance 0.0
#  Feature: language_Indonesian, importance 0.0
#  Feature: language_Italian, importance 0.0
#  Feature: language_Japanese, importance 0.0
#  Feature: language_Kannada, importance 0.0
#  Feature: language_Kazakh, importance 0.0
#  Feature: language_Korean, importance 0.0
#  Feature: language_Mandarin, importance 0.0
#  Feature: language_Maya, importance 0.0
#  Feature: language_Mongolian, importance 0.0
#  Feature: language_Norwegian, importance 0.0
#  Feature: language_Panjabi, importance 0.0
#  Feature: language_Persian, importance 0.0
#  Feature: language_Polish, importance 0.0
#  Feature: language_Portuguese, importance 0.0
#  Feature: language_Romanian, importance 0.0
#  Feature: language_Russian, importance 0.0
#  Feature: language_Slovenian, importance 0.0
#  Feature: language_Spanish, importance 0.0
#  Feature: language_Swahili, importance 0.0
#  Feature: language_Swedish, importance 0.0
#  Feature: language_Tamil, importance 0.0
#  Feature: language_Telugu, importance 0.0
#  Feature: language_Thai, importance 0.0
#  Feature: language_Urdu, importance 0.0
#  Feature: language_Vietnamese, importance 0.0
#  Feature: language_Zulu, importance 0.0
#  Feature: country_Argentina, importance 0.0
#  Feature: country_Aruba, importance 0.0
#  Feature: country_Australia, importance 0.0
#  Feature: country_Bahamas, importance 0.0
#  Feature: country_Belgium, importance 0.0
#  Feature: country_Brazil, importance 0.0
#  Feature: country_Bulgaria, importance 0.0
#  Feature: country_Cambodia, importance 0.0
#  Feature: country_Cameroon, importance 0.0
#  Feature: country_Canada, importance 0.0
#  Feature: country_Chile, importance 0.0
#  Feature: country_China, importance 0.0
#  Feature: country_Colombia, importance 0.0
#  Feature: country_Czech Republic, importance 0.0
#  Feature: country_Denmark, importance 0.0
#  Feature: country_Dominican Republic, importance 0.0
#  Feature: country_Egypt, importance 0.0
#  Feature: country_Finland, importance 0.0
#  Feature: country_France, importance 0.0
#  Feature: country_Georgia, importance 0.0
#  Feature: country_Germany, importance 0.0
#  Feature: country_Greece, importance 0.0
#  Feature: country_Hong Kong, importance 0.0
#  Feature: country_Hungary, importance 0.0
#  Feature: country_Iceland, importance 0.0
#  Feature: country_India, importance 0.0
#  Feature: country_Indonesia, importance 0.0
#  Feature: country_Iran, importance 0.0
#  Feature: country_Ireland, importance 0.0
#  Feature: country_Israel, importance 0.0
#  Feature: country_Italy, importance 0.007694606271749242
#  Feature: country_Japan, importance 0.0
#  Feature: country_Kenya, importance 0.0
#  Feature: country_Kyrgyzstan, importance 0.0
#  Feature: country_Libya, importance 0.0
#  Feature: country_Mexico, importance 0.0
#  Feature: country_Netherlands, importance 0.0
#  Feature: country_New Line, importance 0.0
#  Feature: country_New Zealand, importance 0.0
#  Feature: country_Nigeria, importance 0.0
#  Feature: country_Norway, importance 0.0
#  Feature: country_Official site, importance 0.0
#  Feature: country_Pakistan, importance 0.0
#  Feature: country_Panama, importance 0.0
#  Feature: country_Peru, importance 0.0
#  Feature: country_Philippines, importance 0.0
#  Feature: country_Poland, importance 0.0
#  Feature: country_Romania, importance 0.0
#  Feature: country_Russia, importance 0.0
#  Feature: country_Slovakia, importance 0.0
#  Feature: country_Slovenia, importance 0.0
#  Feature: country_South Africa, importance 0.0
#  Feature: country_South Korea, importance 0.004250869334178952
#  Feature: country_Soviet Union, importance 0.0
#  Feature: country_Spain, importance 0.0
#  Feature: country_Sweden, importance 0.0
#  Feature: country_Switzerland, importance 0.0
#  Feature: country_Taiwan, importance 0.0
#  Feature: country_Thailand, importance 0.0
#  Feature: country_Turkey, importance 0.0
#  Feature: country_UK, importance 0.0
#  Feature: country_USA, importance 0.022350199700687627
#  Feature: country_United Arab Emirates, importance 0.0
#  Feature: country_West Germany, importance 0.0
#  Feature: content_rating_G, importance 0.0026557913616501853
#  Feature: content_rating_GP, importance 0.0
#  Feature: content_rating_M, importance 0.0
#  Feature: content_rating_NC-17, importance 0.0
#  Feature: content_rating_Not Rated, importance 0.0
#  Feature: content_rating_PG, importance 0.0
#  Feature: content_rating_PG-13, importance 0.015932305654290366
#  Feature: content_rating_Passed, importance 0.0
#  Feature: content_rating_R, importance 0.0
#  Feature: content_rating_TV-14, importance 0.004260989742575181
#  Feature: content_rating_TV-G, importance 0.0
#  Feature: content_rating_TV-MA, importance 0.0
#  Feature: content_rating_TV-PG, importance 0.0
#  Feature: content_rating_TV-Y, importance 0.0
#  Feature: content_rating_TV-Y7, importance 0.0
#  Feature: content_rating_Unrated, importance 0.0
#  Feature: content_rating_X, importance 0.0006707328653724713

# %% [markdown]
# #16 Use the predict method on the test data and print out the results.

# %%
y_pred = grid_search.best_estimator_.predict(X_test)
y_pred
# Out:
# array([6.62094241, 6.21145511, 5.39969183, 8.76666667, 6.24365672,
#        7.87894737, 7.75517241, 6.2       , 6.665     , 5.39969183,
#        5.39969183, 6.6173913 , 6.80050761, 6.24365672, 6.97692308,
#        6.25661376, 6.21145511, 7.16818182, 5.39969183, 6.21145511,
#        6.21145511, 6.02553191, 5.39969183, 7.03645833, 5.39969183,
#        6.62094241, 6.80050761, 7.46233766, 6.21145511, 5.39969183,
#        6.96865672, 7.34      , 5.96444444, 7.75517241, 8.        ,
#        7.36666667, 6.15744681, 6.626     , 6.96865672, 6.96865672,
#        6.25661376, 7.34      , 6.62094241, 6.626     , 6.24365672,
#        5.39969183, 6.21145511, 7.61818182, 6.25921053, 5.6287037 ,
#        6.25921053, 5.39969183, 7.08888889, 8.1625    , 6.80050761,
#        6.21145511, 5.6287037 , 6.02553191, 6.09411765, 6.21145511,
# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)

# Print and comment on the evaluation metrics
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R^2): {r_squared}")


"""
The model generalizes well to the test data, with a little less than 1 point off the imdb_score on average.
"""
# Out:
# Mean Absolute Error (MAE): 0.6952281502575215
# Mean Squared Error (MSE): 0.9263197108906793
# R-squared (R^2): 0.36547633249236244
# '\nThe model generalizes well to the test data, with a little less than 1 point off the imdb_score on average.\n'

# %% [markdown]
# #18 Print out the confusion matrix for the test data, what does it tell you about the model?

# %%
# confusion matrix does not apply to regression tasks

# %% [markdown]
# #19 What are the top 3 movies based on the test set? Which variables are most important in predicting the top 3 movies?

# %%
y_pred_series = pd.Series(y_pred, name='Predicted IMDB')
X_preds_concat = pd.concat([y_pred_series, X_test.reset_index(drop=True)], axis=1)


"""
The most essential columns in predicting the imdb score appear to be duration, num_voted_users, and budget among others with smaller impacts
"""

#top 5 predicted rated movies
X_preds_concat.sort_values(by="Predicted IMDB", ascending=False).head()
# Out:
#      Predicted IMDB  num_critic_for_reviews  duration  \
# 3          8.766667                   645.0     152.0
# 185        8.733333                   253.0     146.0
# 245        8.550000                   103.0      44.0
# 168        8.550000                    79.0      22.0
# 238        8.525000                   162.0     101.0
#
#      director_facebook_likes  actor_3_facebook_likes  actor_1_facebook_likes  \
# 3               22000.000000                 11000.0                 23000.0
# 185                 0.000000                   413.0                   888.0
# 245               686.509212                   148.0                   544.0
# 168               686.509212                   424.0                   813.0
# 238               194.000000                   602.0                  1000.0
#
#             gross  num_voted_users  cast_total_facebook_likes  \
# 3    5.333161e+08        1676169.0                    57802.0
# 185  4.846841e+07         610333.0                     2560.0
# 245  4.846841e+07         159910.0                      996.0
# 168  4.846841e+07         133415.0                     1784.0
# 238  6.712241e+06         782437.0                     3858.0
#
#      facenumber_in_poster  num_user_for_reviews        budget   title_year  \
# 3                     0.0                4667.0  1.850000e+08  2008.000000
# 185                   0.0                1320.0  1.900000e+07  1980.000000
# 245                   1.0                 270.0  3.975262e+07  2002.470517
# 168                   5.0                 151.0  3.975262e+07  2002.470517
# 238                   2.0                1420.0  7.500000e+06  1998.000000
#
#      actor_2_facebook_likes  aspect_ratio  movie_facebook_likes  \
# 3                   13000.0          2.35               37000.0
# 185                   629.0          1.37               37000.0
# 245                   183.0          1.78               59000.0
# 168                   547.0          1.33                   0.0
# 238                   816.0          1.85               35000.0
#
#      language_Arabic  language_Aramaic  language_Bosnian  language_Cantonese  \
# 3              False             False             False               False
# 185            False             False             False               False
# 245            False             False             False               False
# 168            False             False             False               False
# 238            False             False             False               False
#
#      language_Chinese  language_Czech  language_Danish  language_Dari  \
# 3               False           False            False          False
# 185             False           False            False          False
# 245             False           False            False          False
# 168             False           False            False          False
# 238             False           False            False          False
#
#      language_Dutch  language_Dzongkha  language_English  language_Filipino  \
# 3             False              False              True              False
# 185           False              False              True              False
# 245           False              False              True              False
# 168           False              False              True              False
# 238           False              False              True              False
#
#      language_French  language_German  language_Greek  language_Hebrew  \
# 3              False            False           False            False
# 185            False            False           False            False
# 245            False            False           False            False
# 168            False            False           False            False
# 238            False            False           False            False
#
#      language_Hindi  language_Hungarian  language_Icelandic  \
# 3             False               False               False
# 185           False               False               False
# 245           False               False               False
# 168           False               False               False
# 238           False               False               False
#
#      language_Indonesian  language_Italian  language_Japanese  \
# 3                  False             False              False
# 185                False             False              False
# 245                False             False              False
# 168                False             False              False
# 238                False             False              False
#
#      language_Kannada  language_Kazakh  language_Korean  language_Mandarin  \
# 3               False            False            False              False
# 185             False            False            False              False
# 245             False            False            False              False
# 168             False            False            False              False
# 238             False            False            False              False
#
#      language_Maya  language_Mongolian  language_Norwegian  language_Panjabi  \
# 3            False               False               False             False
# 185          False               False               False             False
# 245          False               False               False             False
# 168          False               False               False             False
# 238          False               False               False             False
#
#      language_Persian  language_Polish  language_Portuguese  \
# 3               False            False                False
# 185             False            False                False
# 245             False            False                False
# 168             False            False                False
# 238             False            False                False
#
#      language_Romanian  language_Russian  language_Slovenian  \
# 3                False             False               False
# 185              False             False               False
# 245              False             False               False
# 168              False             False               False
# 238              False             False               False
#
#      language_Spanish  language_Swahili  language_Swedish  language_Tamil  \
# 3               False             False             False           False
# 185             False             False             False           False
# 245             False             False             False           False
# 168             False             False             False           False
# 238             False             False             False           False
#
#      language_Telugu  language_Thai  language_Urdu  language_Vietnamese  \
# 3              False          False          False                False
# 185            False          False          False                False
# 245            False          False          False                False
# 168            False          False          False                False
# 238            False          False          False                False
#
#      language_Zulu  country_Argentina  country_Aruba  country_Australia  \
# 3            False              False          False              False
# 185          False              False          False              False
# 245          False              False          False              False
# 168          False              False          False              False
# 238          False              False          False              False
#
#      country_Bahamas  country_Belgium  country_Brazil  country_Bulgaria  \
# 3              False            False           False             False
# 185            False            False           False             False
# 245            False            False           False             False
# 168            False            False           False             False
# 238            False            False           False             False
#
#      country_Cambodia  country_Cameroon  country_Canada  country_Chile  \
# 3               False             False           False          False
# 185             False             False           False          False
# 245             False             False           False          False
# 168             False             False           False          False
# 238             False             False           False          False
#
#      country_China  country_Colombia  country_Czech Republic  country_Denmark  \
# 3            False             False                   False            False
# 185          False             False                   False            False
# 245          False             False                   False            False
# 168          False             False                   False            False
# 238          False             False                   False            False
#
#      country_Dominican Republic  country_Egypt  country_Finland  \
# 3                         False          False            False
# 185                       False          False            False
# 245                       False          False            False
# 168                       False          False            False
# 238                       False          False            False
#
#      country_France  country_Georgia  country_Germany  country_Greece  \
# 3             False            False            False           False
# 185           False            False            False           False
# 245           False            False            False           False
# 168           False            False            False           False
# 238           False            False            False           False
#
#      country_Hong Kong  country_Hungary  country_Iceland  country_India  \
# 3                False            False            False          False
# 185              False            False            False          False
# 245              False            False            False          False
# 168              False            False            False          False
# 238              False            False            False          False
#
#      country_Indonesia  country_Iran  country_Ireland  country_Israel  \
# 3                False         False            False           False
# 185              False         False            False           False
# 245              False         False            False           False
# 168              False         False            False           False
# 238              False         False            False           False
#
#      country_Italy  country_Japan  country_Kenya  country_Kyrgyzstan  \
# 3            False          False          False               False
# 185          False          False          False               False
# 245          False          False          False               False
# 168          False          False          False               False
# 238          False          False          False               False
#
#      country_Libya  country_Mexico  country_Netherlands  country_New Line  \
# 3            False           False                False             False
# 185          False           False                False             False
# 245          False           False                False             False
# 168          False           False                False             False
# 238          False           False                False             False
#
#      country_New Zealand  country_Nigeria  country_Norway  \
# 3                  False            False           False
# 185                False            False           False
# 245                False            False           False
# 168                False            False           False
# 238                False            False           False
#
#      country_Official site  country_Pakistan  country_Panama  country_Peru  \
# 3                    False             False           False         False
# 185                  False             False           False         False
# 245                  False             False           False         False
# 168                  False             False           False         False
# 238                  False             False           False         False
#
#      country_Philippines  country_Poland  country_Romania  country_Russia  \
# 3                  False           False            False           False
# 185                False           False            False           False
# 245                False           False            False           False
# 168                False           False            False           False
# 238                False           False            False           False
#
#      country_Slovakia  country_Slovenia  country_South Africa  \
# 3               False             False                 False
# 185             False             False                 False
# 245             False             False                 False
# 168             False             False                 False
# 238             False             False                 False
#
#      country_South Korea  country_Soviet Union  country_Spain  country_Sweden  \
# 3                  False                 False          False           False
# 185                False                 False          False           False
# 245                False                 False          False           False
# 168                False                 False          False           False
# 238                False                 False          False           False
#
#      country_Switzerland  country_Taiwan  country_Thailand  country_Turkey  \
# 3                  False           False             False           False
# 185                False           False             False           False
# 245                False           False             False           False
# 168                False           False             False           False
# 238                False           False             False           False
#
#      country_UK  country_USA  country_United Arab Emirates  \
# 3         False         True                         False
# 185       False         True                         False
# 245       False         True                         False
# 168       False         True                         False
# 238       False         True                         False
#
#      country_West Germany  content_rating_G  content_rating_GP  \
# 3                   False             False              False
# 185                 False             False              False
# 245                 False             False              False
# 168                 False             False              False
# 238                 False             False              False
#
#      content_rating_M  content_rating_NC-17  content_rating_Not Rated  \
# 3               False                 False                     False
# 185             False                 False                     False
# 245             False                 False                     False
# 168             False                 False                     False
# 238             False                 False                     False
#
#      content_rating_PG  content_rating_PG-13  content_rating_Passed  \
# 3                False                  True                  False
# 185              False                 False                  False
# 245              False                 False                  False
# 168              False                 False                  False
# 238              False                 False                  False
#
#      content_rating_R  content_rating_TV-14  content_rating_TV-G  \
# 3               False                 False                False
# 185              True                 False                False
# 245             False                  True                False
# 168             False                 False                False
# 238              True                 False                False
#
#      content_rating_TV-MA  content_rating_TV-PG  content_rating_TV-Y  \
# 3                   False                 False                False
# 185                 False                 False                False
# 245                 False                 False                False
# 168                  True                 False                False
# 238                 False                 False                False
#
#      content_rating_TV-Y7  content_rating_Unrated  content_rating_X
# 3                   False                   False             False
# 185                 False                   False             False
# 245                 False                   False             False
# 168                 False                   False             False
# 238                 False                   False             False

# %% [markdown]
# #20 Summarize what you learned along the way and make recommendations on how this could be used moving forward, being careful not to over promise.

# %%
"""
The model performs relatively well, the only disappointing factor at the moment is the implementation of scikit learns decision tree regressor. Because it does not allow non-numeric values, many of our categorical
variables had to be given up for the sake of the datasets dimensionality not getting out of control. Had the implementation supported categorical variables, we could have included all actor names as well as movie titles
which could certainly be impactful. Other than that, the model performs well and generalizes nicely to new data, improvements could likely be made in pipelining and generalizing the preprocessing steps, but the proof of 
concept is here. 
"""
x = 1
